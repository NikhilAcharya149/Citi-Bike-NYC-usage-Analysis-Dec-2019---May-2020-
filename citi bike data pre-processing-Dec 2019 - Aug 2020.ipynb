# %%
import pandas as pd
from datetime import *

# %%
df1 = pd.read_csv("C:/citibike/JC-201912-citibike-tripdata.csv")
df2 = pd.read_csv("C:/citibike/JC-202001-citibike-tripdata.csv")
df3 = pd.read_csv("C:/citibike/JC-202002-citibike-tripdata.csv")
df4 = pd.read_csv("C:/citibike/JC-202003-citibike-tripdata.csv")
df5 = pd.read_csv("C:/citibike/JC-202004-citibike-tripdata.csv")
df6 = pd.read_csv("C:/citibike/JC-202005-citibike-tripdata.csv")
df7 = pd.read_csv("C:/citibike/JC-202006-citibike-tripdata.csv")
df8 = pd.read_csv("C:/citibike/JC-202007-citibike-tripdata.csv")
df9 = pd.read_csv("C:/citibike/JC-202008-citibike-tripdata.csv")

# %%
df_all = [df1, df2, df3, df4, df5, df6, df7, df8, df9]

# %%
for i in range(len(df_all)):
    df_all[i]['start_time_date'] = pd.to_datetime(df_all[i]['starttime']).dt.date
    df_all[i]['start_time'] = pd.to_datetime(df_all[i]['starttime']).dt.time
    df_all[i]['stop_time_date'] = pd.to_datetime(df_all[i]['stoptime']).dt.date
    df_all[i]['stop_time'] = pd.to_datetime(df_all[i]['stoptime']).dt.time

# %%
df1.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1553  2019-12-01 00:07:13.9360  2019-12-01 00:33:07.6820
# 1           416  2019-12-01 00:16:40.4700  2019-12-01 00:23:36.5700
# 2           294  2019-12-01 00:20:29.7980  2019-12-01 00:25:23.9690
# 3            97  2019-12-01 00:21:13.7580  2019-12-01 00:22:51.5970
# 4           286  2019-12-01 00:29:58.0230  2019-12-01 00:34:44.2280
#
#    start station id start station name  start station latitude  \
# 0              3681           Grand St               40.715178
# 1              3195            Sip Ave               40.730897
# 2              3195            Sip Ave               40.730897
# 3              3202       Newport PATH               40.727224
# 4              3195            Sip Ave               40.730897
#
#    start station longitude  end station id  end station name  \
# 0               -74.037683            3198  Heights Elevator
# ...

# %%
df7.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           122  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250
# 1          1282  2020-06-01 00:12:27.1090  2020-06-01 00:33:50.0540
# 2           186  2020-06-01 01:19:59.2090  2020-06-01 01:23:05.8930
# 3           131  2020-06-01 01:26:42.2050  2020-06-01 01:28:53.8040
# 4           266  2020-06-01 01:27:33.7090  2020-06-01 01:32:00.1890
#
#    start station id          start station name  start station latitude  \
# 0              3792  Columbus Dr at Exchange Pl               40.716870
# 1              3198            Heights Elevator               40.748716
# 2              3275              Columbus Drive               40.718355
# 3              3267                Morris Canal               40.712419
# 4              3639                  Harborside               40.719252
#
#    start station longitude  end station id  end station name  \
# ...

# %%
new_df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9])
print(new_df)
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1553  2019-12-01 00:07:13.9360  2019-12-01 00:33:07.6820
# 1               416  2019-12-01 00:16:40.4700  2019-12-01 00:23:36.5700
# 2               294  2019-12-01 00:20:29.7980  2019-12-01 00:25:23.9690
# 3                97  2019-12-01 00:21:13.7580  2019-12-01 00:22:51.5970
# 4               286  2019-12-01 00:29:58.0230  2019-12-01 00:34:44.2280
# ...             ...                       ...                       ...
# 43262           162  2020-08-31 23:43:15.8540  2020-08-31 23:45:58.4550
# 43263           400  2020-08-31 23:46:19.9130  2020-08-31 23:53:00.3610
# 43264           288  2020-08-31 23:47:16.8680  2020-08-31 23:52:05.5550
# 43265           199  2020-08-31 23:50:37.2650  2020-08-31 23:53:56.9490
# 43266           333  2020-08-31 23:55:30.8050  2020-09-01 00:01:04.4110
#
#        start station id start station name  start station latitude  \
# ...

# %%
df1 =  df1.to_csv('C:/citibike/dec 2019.csv', encoding='utf-8', index=False)
df2 =  df2.to_csv('C:/citibike/jan 2020.csv', encoding='utf-8', index=False)
df3 =  df3.to_csv('C:/citibike/feb 2020.csv', encoding='utf-8', index=False)
df4 =  df4.to_csv('C:/citibike/mar 2020.csv', encoding='utf-8', index=False)
df5 =  df5.to_csv('C:/citibike/apr 2020.csv', encoding='utf-8', index=False)
df6 =  df6.to_csv('C:/citibike/may 2020.csv', encoding='utf-8', index=False)
df7 =  df7.to_csv('C:/citibike/jun 2020.csv', encoding='utf-8', index=False)
df8 =  df8.to_csv('C:/citibike/jul 2020.csv', encoding='utf-8', index=False)
df9 =  df9.to_csv('C:/citibike/aug 2020.csv', encoding='utf-8', index=False)

# %%
print(new_df)
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1553  2019-12-01 00:07:13.9360  2019-12-01 00:33:07.6820
# 1               416  2019-12-01 00:16:40.4700  2019-12-01 00:23:36.5700
# 2               294  2019-12-01 00:20:29.7980  2019-12-01 00:25:23.9690
# 3                97  2019-12-01 00:21:13.7580  2019-12-01 00:22:51.5970
# 4               286  2019-12-01 00:29:58.0230  2019-12-01 00:34:44.2280
# ...             ...                       ...                       ...
# 43262           162  2020-08-31 23:43:15.8540  2020-08-31 23:45:58.4550
# 43263           400  2020-08-31 23:46:19.9130  2020-08-31 23:53:00.3610
# 43264           288  2020-08-31 23:47:16.8680  2020-08-31 23:52:05.5550
# 43265           199  2020-08-31 23:50:37.2650  2020-08-31 23:53:56.9490
# 43266           333  2020-08-31 23:55:30.8050  2020-09-01 00:01:04.4110
#
#        start station id start station name  start station latitude  \
# ...

# %%
new_df['gender'].replace([0,1,2],['unknown','Male','Female'],inplace=True)

# %%
new_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1553  2019-12-01 00:07:13.9360  2019-12-01 00:33:07.6820
# 1           416  2019-12-01 00:16:40.4700  2019-12-01 00:23:36.5700
# 2           294  2019-12-01 00:20:29.7980  2019-12-01 00:25:23.9690
# 3            97  2019-12-01 00:21:13.7580  2019-12-01 00:22:51.5970
# 4           286  2019-12-01 00:29:58.0230  2019-12-01 00:34:44.2280
#
#    start station id start station name  start station latitude  \
# 0              3681           Grand St               40.715178
# 1              3195            Sip Ave               40.730897
# 2              3195            Sip Ave               40.730897
# 3              3202       Newport PATH               40.727224
# 4              3195            Sip Ave               40.730897
#
#    start station longitude  end station id  end station name  \
# 0               -74.037683            3198  Heights Elevator
# ...

# %%
new_df = new_df.to_csv('C:/citibike/dec 2019-Augs 2020.csv', encoding='utf-8', index=False)
